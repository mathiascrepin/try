# %% [markdown]
# <a href="https://colab.research.google.com/github/mathiascrepin/HTML_CSS/blob/master/Copie_de_analyse_donn%C3%A9es_covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importation des donnees 

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
  # importation des données 
confirmed_us=pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv')
confirmed_global=pd.read_csv('https://github.com/CSSEGISandData/COVID-19/raw/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
death_us = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv')
death_global= pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
revorvered_global= pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %%
# voir la taille des tableaux 

print(confirmed_us.shape)
print(confirmed_global.shape)
print(death_us.shape)
print(death_global.shape)
print(revorvered_global.shape)
# Out:
# (3340, 250)
# (266, 243)
# (3340, 251)
# (266, 243)
# (253, 243)

# %%
confirmed_global.head(15)
# Out:
#                   Province/State       Country/Region  ...  9/15/20  9/16/20
# 0                            NaN          Afghanistan  ...    38815    38855
# 1                            NaN              Albania  ...    11672    11816
# 2                            NaN              Algeria  ...    48734    48966
# 3                            NaN              Andorra  ...     1438     1483
# 4                            NaN               Angola  ...     3569     3675
# 5                            NaN  Antigua and Barbuda  ...       95       95
# 6                            NaN            Argentina  ...   577338   589012
# 7                            NaN              Armenia  ...    46119    46376
# 8   Australian Capital Territory            Australia  ...      113      113
# 9                New South Wales            Australia  ...     4185     4190
# 10            Northern Territory            Australia  ...       33       33
# ...

# %%
death_global.head(15)
# Out:
#                   Province/State       Country/Region  ...  9/15/20  9/16/20
# 0                            NaN          Afghanistan  ...     1426     1436
# 1                            NaN              Albania  ...      340      343
# 2                            NaN              Algeria  ...     1632     1645
# 3                            NaN              Andorra  ...       53       53
# 4                            NaN               Angola  ...      139      143
# 5                            NaN  Antigua and Barbuda  ...        3        3
# 6                            NaN            Argentina  ...    11852    12116
# 7                            NaN              Armenia  ...      920      923
# 8   Australian Capital Territory            Australia  ...        3        3
# 9                New South Wales            Australia  ...       52       52
# 10            Northern Territory            Australia  ...        0        0
# ...

# %%
death_global.head(10)
# Out:
#                  Province/State       Country/Region  ...  9/15/20  9/16/20
# 0                           NaN          Afghanistan  ...     1426     1436
# 1                           NaN              Albania  ...      340      343
# 2                           NaN              Algeria  ...     1632     1645
# 3                           NaN              Andorra  ...       53       53
# 4                           NaN               Angola  ...      139      143
# 5                           NaN  Antigua and Barbuda  ...        3        3
# 6                           NaN            Argentina  ...    11852    12116
# 7                           NaN              Armenia  ...      920      923
# 8  Australian Capital Territory            Australia  ...        3        3
# 9               New South Wales            Australia  ...       52       52
#
# [10 rows x 243 columns]

# %%
death_global[death_global['Country/Region']=='China']
# Out:
#     Province/State Country/Region      Lat  ...  9/14/20  9/15/20  9/16/20
# 56           Anhui          China  31.8257  ...        6        6        6
# 57         Beijing          China  40.1824  ...        9        9        9
# 58       Chongqing          China  30.0572  ...        6        6        6
# 59          Fujian          China  26.0789  ...        1        1        1
# 60           Gansu          China  35.7518  ...        2        2        2
# 61       Guangdong          China  23.3417  ...        8        8        8
# 62         Guangxi          China  23.8298  ...        2        2        2
# 63         Guizhou          China  26.8154  ...        2        2        2
# 64          Hainan          China  19.1959  ...        6        6        6
# 65           Hebei          China  39.5490  ...        6        6        6
# 66    Heilongjiang          China  47.8620  ...       13       13       13
# ...

# %%
# afficher uniquement les données du Benin 

death_global[death_global['Country/Region']=='Benin']
# Out:
#    Province/State Country/Region     Lat  ...  9/14/20  9/15/20  9/16/20
# 25            NaN          Benin  9.3077  ...       40       40       40
#
# [1 rows x 243 columns]

# %%
 # afficher toute  les colonnes

 death_global.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '9/7/20', '9/8/20', '9/9/20', '9/10/20', '9/11/20', '9/12/20',
#        '9/13/20', '9/14/20', '9/15/20', '9/16/20'],
#       dtype='object', length=243)

# %%
# afficher les statistique niveau mondiale
